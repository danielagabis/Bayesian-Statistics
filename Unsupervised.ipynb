# %% [markdown]
# <a href="https://colab.research.google.com/github/danielagabis/Bayesian-Statistics/blob/main/Unsupervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/danielagabis/Bayesian-Statistics/main/Unsupervised_data.xlsx"
data = pd.read_excel(url)

print("Dataset Preview:")
print(data.head())

X = data.select_dtypes(include=['float64', 'int64'])

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)

clusters = kmeans.fit_predict(X)

data['Cluster'] = clusters

print("\nClustered Data Sample:")
print(data.head())

plt.scatter(X.iloc[:,0], X.iloc[:,1], c=clusters)
plt.xlabel(X.columns[0])
plt.ylabel(X.columns[1])
plt.title("K-Means Clustering Result")
plt.show()
# Out:
# Dataset Preview:
#    Age  Annual_Income  Spending_Score
# 0   27          70864              24
# 1   46          55621              17
# 2   53         110555             100
# 3   33         109328              80
# 4   20          37895              17
#
# Clustered Data Sample:
#    Age  Annual_Income  Spending_Score  Cluster
# 0   27          70864              24        0
# 1   46          55621              17        0
# 2   53         110555             100        2
# 3   33         109328              80        2
# 4   20          37895              17        1
